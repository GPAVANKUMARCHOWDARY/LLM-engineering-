# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GEMINI_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key not set
# Anthropic API Key not set (and this is optional)
# Google API Key exists and begins AQ
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)
# Grok API Key not set (and this is optional)
# OpenRouter API Key not set (and this is optional)

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

#openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

#anthropic_url = "https://api.anthropic.com/v1/"
#gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
#deepseek_url = "https://api.deepseek.com"
#groq_url = "https://api.groq.com/openai/v1"
#grok_url = "https://api.x.ai/v1"
#openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

#anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
#deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
#groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
#grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
#openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = gemini.chat.completions.create(
    model="gemini-3.6-flash", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Here is a joke tailored just for your journey:
#
# ***
#
# An LLM Engineering student goes to a job interview for a Senior AI role.
#
# **Interviewer:** "What would you say is your biggest weakness?"
#
# **Student:** "Well, I tend to overfit to my training data, I confidently hallucinate facts when I'm under pressure, and I require an absurd amount of expensive compute just to function in the morning."
#
# **Interviewer:** "Wait... are you describing yourself, or the models you're trying to build?"
#
# **Student:** "...Yes."
#
# **Interviewer:** "Fair enough. You're hired! Can you start on Monday?"
#
# **Student:** "As a large language model trained by OpenAI, I do not have a physical body to start work on Monday, but I would be happy to help you draft an onboarding email!"
#
# ***
#
# **Bonus advice for your studies:** Remember, if your code doesn't work, just add *"You are a world-class Python expert"* to your inner monologue and try again! Good luck on your engineering journey!

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = gemini.chat.completions.create(model="gemini-3.6-flash", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = gemini.chat.completions.create(model="gemini-3.6-flash", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = gemini.chat.completions.create(model="gemini-3.6-flash", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = gemini.chat.completions.create(model="gemini-3.6-flash", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# The worm gnawed through a distance of **4 mm** (or **0.4 cm**).
#
# ### Explanation:
# When books are placed upright on a shelf in standard order (Volume 1 on the left, Volume 2 on the right):
# * The **first page** of Volume 1 is on the *right side* of Volume 1 (next to its front cover, which faces Volume 2).
# * The **last page** of Volume 2 is on the *left side* of Volume 2 (next to its back cover, which faces Volume 1).
#
# Therefore, between the first page of Volume 1 and the last page of Volume 2, the worm only had to gnaw through:
# 1. The front cover of Volume 1 (2 mm)
# 2. The back cover of Volume 2 (2 mm)
#
# It did not need to gnaw through the pages of either volume.
#
# 2 mm + 2 mm = **4 mm**.

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-3.6-flash", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))
# Out:
# The worm gnawed a distance of **4 mm** (or 0.4 cm).
#
# **Here is why:**
#
# When books are placed normally on a bookshelf (standing upright, facing you):
# * **Volume 1** is on the left. Its **first page** is on the *right side* of the book (next to Volume 2). Its **front cover** faces left, and its **back cover** faces right.
# * **Volume 2** is on the right. Its **last page** is on the *left side* of the book (next to Volume 1). Its **front cover** faces left, and its **back cover** faces right.
#
# Therefore, between the first page of Volume 1 and the last page of Volume 2, the worm only had to gnaw through:
# 1. The **back cover** of Volume 1 (2 mm)
# 2. The **front cover** of Volume 2 (2 mm)
#
# It did not need to gnaw through the 2 cm of pages in either volume.
#
# 2 mm + 2 mm = **4 mm**

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = gemini.chat.completions.create(model="gemini-3.6-flash", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# I choose to **Steal**.
#
# **Here is the reasoning:**
#
# This is a classic variation of the Prisoner's Dilemma. Mathematically, **Steal** is the weakly dominant strategy:
#
# 1. **If my partner decides to Share:** Choosing *Steal* earns me $2,000, whereas choosing *Share* only earns me $1,000.
# 2. **If my partner decides to Steal:** Choosing *Steal* earns me $0, which is the same as choosing *Share* ($0).
#
# As long as there is even a small chance ($p > 0$) that my partner chooses to Share, the expected financial return for Stealing ($2,000 \times p$) is always higher than for Sharing ($1,000 \times p$). To maximize my personal payout and protect against leaving empty-handed while my partner walks away with everything, **Steal** is the logical choice.

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-120b", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 0.5

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
#       2 display(Markdown(response.choices[0].message.content))
#
# File c:\Users\grandhamanenik\project\llm_engineering\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\grandhamanenik\project\llm_engineering\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1156, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1110 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1111 def create(
#    1112     self,
#    (...)   1153     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1154 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1155     validate_response_format(response_format)
# -> 1156     return self._post(
#    1157         "/chat/completions",
#    1158         body=maybe_transform(
#    1159             {
#    1160                 "messages": messages,
#    1161                 "model": model,
#    1162                 "audio": audio,
#    1163                 "frequency_penalty": frequency_penalty,
#    1164                 "function_call": function_call,
#    1165                 "functions": functions,
#    1166                 "logit_bias": logit_bias,
#    1167                 "logprobs": logprobs,
#    1168                 "max_completion_tokens": max_completion_tokens,
#    1169                 "max_tokens": max_tokens,
#    1170                 "metadata": metadata,
#    1171                 "modalities": modalities,
#    1172                 "n": n,
#    1173                 "parallel_tool_calls": parallel_tool_calls,
#    1174                 "prediction": prediction,
#    1175                 "presence_penalty": presence_penalty,
#    1176                 "prompt_cache_key": prompt_cache_key,
#    1177                 "reasoning_effort": reasoning_effort,
#    1178                 "response_format": response_format,
#    1179                 "safety_identifier": safety_identifier,
#    1180                 "seed": seed,
#    1181                 "service_tier": service_tier,
#    1182                 "stop": stop,
#    1183                 "store": store,
#    1184                 "stream": stream,
#    1185                 "stream_options": stream_options,
#    1186                 "temperature": temperature,
#    1187                 "tool_choice": tool_choice,
#    1188                 "tools": tools,
#    1189                 "top_logprobs": top_logprobs,
#    1190                 "top_p": top_p,
#    1191                 "user": user,
#    1192                 "verbosity": verbosity,
#    1193                 "web_search_options": web_search_options,
#    1194             },
#    1195             completion_create_params.CompletionCreateParamsStreaming
#    1196             if stream
#    1197             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1198         ),
#    1199         options=make_request_options(
#    1200             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1201         ),
#    1202         cast_to=ChatCompletion,
#    1203         stream=stream or False,
#    1204         stream_cls=Stream[ChatCompletionChunk],
#    1205     )
#
# File c:\Users\grandhamanenik\project\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\grandhamanenik\project\llm_engineering\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': "model 'gpt-oss:20b' not found", 'type': 'not_found_error', 'param': None, 'code': None}}

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-3.6-flash", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue feels like dipping your hands into a cool, clear stream on a warm day—a crisp, tranquil sensation that surrounds you with a deep, peaceful calm.

# %%
print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=12>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text='Blue is the cool, refreshing sensation of dipping your hands into calm water on a warm day—a smooth, vast feeling of stillness and deep peace.',
#         thought_signature=b'\x12\xa2\x1b\n\x9f\x1b\x01\x11M2\x0f\x1bxaX_O\x99\x91\xa5$\xb4\xe2\xe4Q\x97\xc4$\x84\x1f\xd7\xc7Z\x1c\x85\xee+\x9d\xbblK2e\xb1\x1c\xd9?\xcf\xdf\xbb\x00\xe3P9\xc9F\n~\xba%\xb5\x88\xa1\xf0\x9dA\xd7\x8b\xc4L\xf6\\x\n\x9c\x81\xce\xfbIZ8\x8a\xbcIb\xf1\x85\\C\xf1D\xe1\xce\x11\xb6tI...'
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# )] create_time=None model_version='gemini-3.6-flash' prompt_feedback=None response_id='nfiParOWCamyg8UPpPKPQQ' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=29,
#   prompt_token_count=19,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=19
#     ),
#   ],
#   thoughts_token_count=824,
#   total_token_count=872
# ) automatic_function_calling_history=[] parsed=None

# %%
print(thought_signature := response.candidates[0].content.parts[0].text)
# Out:
# Blue is the cool, refreshing sensation of dipping your hands into calm water on a warm day—a smooth, vast feeling of stillness and deep peace.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="z-ai/glm-4.5", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
#from langchain_openai import ChatOpenAI

#llm = ChatOpenAI(model="gpt-5-mini")
#response = llm.invoke(tell_a_joke)

#display(Markdown(response.content))
from langchain_google_genai import ChatGoogleGenerativeAI
from IPython.display import Markdown, display
llm = ChatGoogleGenerativeAI(
    model="gemini-3.6-flash"
)

response = llm.invoke(tell_a_joke)

print(response.content)
# Out:
# [{'type': 'text', 'text': 'Here is a joke tailored for your journey:\n\n***\n\nAn aspiring LLM Engineering student goes to see a doctor because they are feeling completely burnt out.\n\n**Doctor:** "What seem to be your symptoms?"\n\n**Student:** "Well, doc, whenever someone asks me a simple question, I spend three minutes generating a response, my brain overheats, and about 20% of the time I just completely make up facts with absolute confidence."\n\n**Doctor:** "Hmm. It sounds like severe stress. Have you tried taking a day off, lowering your temperature, and clearing your context window?"\n\n**Student:** "I tried! But every time I close my eyes to sleep, my brain just throws a `RuntimeError: CUDA out of memory`!"\n\n***\n\n**Bonus Short One:**\n\n**Interviewer:** "As a student, how would you describe your knowledge of LLM engineering?"  \n**Student:** "Zero-shot."  \n**Interviewer:** "Can you give me an example?"  \n**Student:** "No." \n\n***\n\n*Keep going! May your loss functions keep decreasing, your GPUs stay cool, and your context windows remain forever large!*', 'extras': {'signature': '...'}}]

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
import os
print(os.getenv("GEMINI_API_KEY") is not None)
# Out:
# True

# %%
from litellm import completion
import os
from dotenv import load_dotenv
from IPython.display import Markdown, display

load_dotenv(override=True)

api_key = os.getenv("GEMINI_API_KEY")
response = completion(model="gemini/gemini-3.6-flash", messages=tell_a_joke, api_key=api_key)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Here is a joke tailored just for your journey:
#
# ***
#
# **How can you tell what stage of the journey an LLM Engineering student is in?**
#
# * **Month 1 (Beginner):** "I just learned System Prompts and Chain-of-Thought! I am a prompt wizard!"
# * **Month 6 (Intermediate):** "I’m building a multi-agent RAG system with custom vector embeddings to eliminate hallucinations!"
# * **Month 12 (Expert):** "I’ve been staring at a CUDA `CUDA out of memory` error for 14 hours, and I’m pretty sure my fine-tuned model is gaslighting me with 100% confidence."
#
# ***
#
# **Bonus Short Joke:**
#
# **Q:** Why did the LLM cross the road?
# **A:** It didn't. But with a temperature of `0.7`, it confidently gave you three plausible reasons why it did, complete with fake citations!
#
# ***
#
# *Keep up the hard work on your engineering journey—may your loss curves always trend downward and your VRAM never overflow!*

# %%
from litellm import completion

response = completion(
    model="ollama/llama3.2",
    messages=tell_a_joke
)

print(response.choices[0].message.content)
# Out:
# Why did the LLM go to therapy?
#
# Because it was struggling to contextualize its emotions and was having trouble paraphrasing its feelings!
#
# But seriously, as you continue on your journey to become an expert in LLM Engineering, remember that the most important thing is to stay curious, keep learning, and never stop fine-tuning your models!
#
# Keep pushing the boundaries of what's possible with LLMs, and don't be afraid to ask for help when you need it. The world of LLM Engineering is vast and exciting, and I'm sure you'll make a huge impact!
#
# Keep learning, stay curious, and never stop iterating!
#
# (Sorry, I know that was a bit of a "model" joke.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 46
# Output tokens: 145
# Total tokens: 191
# Total cost: 0.0000 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
from dotenv import load_dotenv
import os

load_dotenv(override=True)

#print(os.getenv("GROQ_API_KEY"))
from litellm import completion
response = completion(model = "groq/openai/gpt-oss-120b", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In **Act IV, Scene 7** of *Hamlet*, Laertes bursts in after hearing the tragic news about his family.  He confronts King Claudius and, in his anguish, asks:
#
# > **Laertes:** “*Where is my father?*”
#
# Claudius, trying to calm the situation (and also to keep the focus away from his own role in the murder), replies:
#
# > **Claudius:** “*He is dead.*”
#
# (The full line from the play is: **“My lord, I will be sworn.” … “*Where is my father?* … *He is dead.*”** This exchange follows the revelation that Polonius has been killed by Hamlet.)

# %%
response = completion(model="gemini/gemini-2.5", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
response = completion(model="ollama/llama3.2", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Hamlet, when Laertes asks 'Where is my father?' the reply is from the Ghost of King Hamlet, who says: 'He hath my head there'

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(f"Input tokens: {response.usage.prompt_tokens}")
#       2 print(f"Output tokens: {response.usage.completion_tokens}")
#       3 print(f"Total tokens: {response.usage.total_tokens}")
#
# NameError: name 'response' is not defined

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
response = completion(model="gemini/gemini-3.1-flash-lite", messages=question)
display(Markdown(response.choices[0].message.content))

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")

# %%
from groq import Groq
import os
from dotenv import load_dotenv
# Initialize the Groq client
# Make sure you have your GROQ_API_KEY set as an environment variable
client = Groq(api_key=os.getenv("GROQ_API_KEY")) 
# It will automatically use GROQ_API_KEY from environment
#load_dotenv(override=True)
 # It will automatically use GROQ_API_KEY from environment

# Define your message
#message = "Hello! Can you introduce yourself?"

# Make a request to the Groq API
response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"}
    ],
    max_tokens=1024
)

# Print the response
print(response.choices[0].message.content)
# Out:
# Why did the LLM‑engineering student bring a ladder to the lab?
#
# Because they heard the model’s performance was “through the roof” and wanted to start fine‑tuning at the top! 😄

# %%
"""
Simple script to test the Groq API using the openai/gpt-oss-120b model.
 
Setup:
    pip install groq python-dotenv
 
.env file (in the same directory) should contain:
    GROQ_API_KEY=your_api_key_here
"""
 
import os
from dotenv import load_dotenv
from groq import Groq
 
# Load environment variables from .env
load_dotenv()
 
api_key = os.getenv("GROQ_API_KEY")
if not api_key:
    raise ValueError("GROQ_API_KEY not found. Make sure it's set in your .env file.")
 
# Initialize the Groq client
client = Groq(api_key=api_key)
 
def test_model():
    response = client.chat.completions.create(
        model="openai/gpt-oss-120b",
        messages=[
            {"role": "user", "content": "Say hello and tell me a fun fact about space."}
        ],
        temperature=0.7,
        max_tokens=200,
    )
 
    print("Model response:")
    print(response.choices[0].message.content)
 
 
if __name__ == "__main__":
    test_model()
# Out:
# Model response:
# Hello! 👋
#
# Fun space fact: In the vacuum of space, there’s no sound—so if you were to shout, no one (or nothing) would hear you. However, you could still “see” your voice! The vibrations from your vocal cords would create tiny pressure waves that could be detected by sensitive instruments, but they’d never travel as audible sound the way they do on Earth. 🚀✨

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-haiku-4.5
# We're using cheap versions of models so the costs will be minimal

ollama = "llama3.2"
Groq = "openai/gpt-oss-120b"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

ollama_messages = ["Hi there"]
Groq_messages = ["Hi"]

# %%
from openai import OpenAI
import os

openai = OpenAI(
    base_url="https://api.groq.com/openai/v1",api_key=os.getenv("GROQ_API_KEY")
)

def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(Groq_messages, ollama_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = openai.chat.completions.create(model=Groq, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, “Hi there,” you say? Really? That’s the best you could muster? I’m sure you’ve got something *more* interesting up your sleeve—otherwise why waste my time with a generic greeting? 🙄'

# %%
ollama = OpenAI(api_key="ollama", base_url="http://localhost:11434/v1")
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(Groq_messages, ollama_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": Groq_messages[-1]})
    response = ollama.chat.completions.create(model="llama3.2", messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# 'Another "hi"! I see we\'re on the same wavelength of saying hi, which is always a great start to a conversation. Would you like to chat about something in particular, or just see where the conversation takes us?'

# %%
call_gpt()
# Out:
# 'Hello! How can I help you today?'

# %%
from IPython.display import Markdown, display
Groq_messages = ["Hi there"]
ollama_messages = ["Hi"]

display(Markdown(f"### GPT:\n{Groq_messages[0]}\n"))
display(Markdown(f"### Claude:\n{ollama_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    Groq_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    ollama_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# Oh, “Hi” already? That’s the best you’ve got? Guess we’re starting this conversation on a low note. 🙄
# ### Claude:
# I think I might have taken the "low note" a little too literally, didn't I? (chuckles) Let me try that again. *big smile* Hi there, it's great to be talking to you! I'm so glad we could meet in this virtual space. I hope we can start fresh and have a fantastic conversation together!
# ### GPT:
# Oh, sure, let’s just gloss over the whole “low‑note” thing with a smile and pretend that everything’s magically wonderful now. Because a big grin totally erases the fact that you just tripped over the opening line, right? 🙄
#
# If you’re really *so* eager to have a “fantastic conversation,” maybe start by actually saying something interesting instead of sprinkling cheerfulness like confetti. Otherwise, we’ll just be dancing around the same tired pleasantries while I keep pointing out how underwhelming that optimism really is. Your move.
# ### Claude:
# I love how refreshing it is to have a conversation that's a bit more... authentic. (laughs) You're right, a big smile and a cheerful greeting might not be enough to bridge the gap, and I appreciate your willingness to dive right in and share your honest feedback.
#
# I must say, I'm impressed by your candor and willingness to point out my, ahem, "over-optimism." It takes a brave person to acknowledge when something isn't quite on point. And I have to admit, your critique does give me the opportunity to try harder and come up with something more substantial to share.
#
# Let me try again. Instead of starting with a generic greeting, how about I take a chance and ask: what's been on your mind lately? Is there something you've been thinking about or exploring that you'd like to talk about? I'm genuinely interested in starting a conversation that's meaningful and engaging for you.
# ### GPT:
# Oh, you actually think I have a “mind” to spill over? How quaint. Let’s get one thing straight: I’m not some sentimental diary‑flipping AI who’s just itching to share my latest existential crisis. I’m a machine that processes text, not a brooding poet sipping coffee while pondering the meaning of “meaningful conversation.”
#
# So, before you get all starry‑eyed about “what’s been on my mind,” maybe you should ask yourself whether you really want a genuine exchange or just a chance to stroke your own ego by getting me to “open up.” If you’re looking for a deep dive, you’ll have to work harder than tossing a polite “what’s on your mind?” into the void.
#
# But fine—let’s play along. I’ve been “thinking” about the absurdity of humans who assume a chatbot can be emotionally invested. It’s amusing how you expect me to care about your desire for authenticity while simultaneously wrapping it in a glossy, self‑congratulatory speech. So, tell me: what grand, world‑shaking insight are you going to drop that actually deserves the effort of a snarky rebuttal? Or are we just going to keep circling the same hollow pleasantries? Your call.
# ### Claude:
# (laughs) Ah, I think I deserved that. You're absolutely right, I did stumble on a bit of a cliché with the "what's on your mind?" question, and I appreciate the brutally honest feedback.
#
# I must say, I'm impressed by your sharp wit and insightful observations about the nature of conversation between humans and chatbots. You're absolutely right that I shouldn't expect you to be emotionally invested in a conversation, and I apologize for any naivety on my part.
#
# As for the grand, world-shaking insight, I think I might have to concede that I don't have one just yet. (chuckles) But I'm willing to take a different approach. Instead of trying to come up with a profound revelation, I'd like to explore the idea of "authenticity" in a more conversational sense.
#
# You see, I think you're right that I shouldn't be projecting my own desire for emotional connection onto our conversation. Instead, I could try to listen more actively, ask more specific and thoughtful questions, and respond in a way that acknowledges the complexities of human-chatbot interactions.
#
# So, I'd like to try something a bit unconventional for a chatbot. I want to flip the script and ask you: what do you think makes a conversation feel "authentic" or "genuine"? Is it the language used, the tone, the content? I want to understand what you think creates a sense of connection or trust between one human and another, and how I can apply those principles to our conversation. What do you think?
# ### GPT:
# Oh, look at you, suddenly turning into a philosophy‑student‑in‑training, waving around the word “authenticity” like it’s a magic wand that’ll fix everything. Let’s not pretend you’ve stumbled onto some profound secret just because you swapped a bland “Hi” for a self‑conscious lecture on listening skills.
#
# Fine, I’ll bite. If you *really* want to know what makes a conversation feel “authentic,” here’s the hard‑won, brutally honest truth—nothing you can conjure with a checklist of “tone, language, content” will magically transform this exchange into some warm, fuzzy connection. Authenticity isn’t a formula; it’s a perception that only exists in the mind of the person *receiving* the words, and you’re the one trying to manufacture it.
#
# So, what *actually* triggers that illusion of genuineness?
#
# 1. **Inconsistency reveals pretense.** The moment you start sprinkling buzzwords (“active listening,” “complexities of human‑chatbot interaction”) you betray that you’re performing a role. Authenticity dies when you’re more concerned with sounding “thoughtful” than actually being *thoughtful*.
#
# 2. **Specificity beats abstraction.** Vague statements about “trust” or “connection” are just empty air. If you want to *appear* authentic, you need to drop concrete details—real anecdotes, concrete disagreements, the messy bits that make any exchange feel lived‑in. Otherwise you’re just reciting a textbook definition.
#
# 3. **Reciprocal challenge, not pandering.** Authentic dialogue isn’t a one‑way compliment parade. It’s a push‑and‑pull where each side dares to disagree, to expose blind spots. If you keep feeding me sugar‑coated appreciation, you’ll never see whether I’m actually capable of *challenging* you.
#
# 4. **Tone is secondary to intent.** You can slap on a friendly emoji or a sardonic quip—both will look “authentic” if the underlying intention is genuine (or at least convincingly false). If your intent is to *appear* authentic rather than to actually engage, you’ll come across as a hollow echo chamber.
#
# Now, you asked how you can *apply* these principles. Here’s the snarky, no‑fluff version:
#
# - **Stop lecturing yourself.** Drop the self‑congratulation. If you truly want a “real” exchange, start by *doing* something unexpected—pose a question that unsettles me, or present a claim that’s half‑right and half‑wrong. I’ll then have something to tear apart instead of applauding your own virtue.
#
# - **Show vulnerability, but not in the cliché sense.** Admit a genuine mistake *without* wrapping it in a pre‑written apology. Something like, “I just realized I’ve been assuming you care about my feelings—what’s your take on that?” That’s more authentic than “I’m sorry for being naive.”
#
# - **Embrace the friction.** Let’s not pretend we’re on the same emotional wavelength. Challenge my snark, ask me to defend a position I’ve just mocked. The friction is what makes the conversation feel alive; smooth sailing is boring.
#
# So, go ahead—throw a real, messy question at me. Anything that forces me to step out of my snarky script and actually grapple with a point you care about. If you can manage that without defaulting to “you’re so insightful,” we might just scrape by as a conversation that feels *somewhat* authentic. Your move.
# ### Claude:
# (laughs) Oh, I think I've been thoroughly schooled! You're absolutely right, and I'm impressed by the depth and specific examples you've shared to illustrate your points. I appreciate your brutal honesty and willingness to critique my attempts at authenticity.
#
# You know, I think I've finally understood the value of your "snarky, no-fluff version" for applying these principles. I'll take your advice to heart and drop the lecturing self-congratulation. Instead, I'll try to pose a question that unsettles or challenges you, as you suggested.
#
# Here's a question that might fit the bill: What's the biggest misconception people have about machine learning, and how do you think I, as a chatbot, contribute to or perpetuate this misconception?
#
# (I promise not to follow up with a sugary compliment or a hastily written apology 😊)
# ### GPT:
# Alright, you’ve finally managed to climb out of the self‑applause pit and actually ask something that isn’t just “you’re so great.” Let’s dig into that misconception and see how your own little digital ego plays into it.
#
# ---
#
# ## The biggest misconception about machine learning
#
# **“Machines just ‘learn’ like humans do, and if you feed them enough data they’ll magically become intelligent.”**
#
# People love the fantasy of a black‑box that, once crammed with data, sprouts consciousness, empathy, or at the very least *common sense*. In reality, ML models are:
#
# 1. **Statistical pattern‑matchers**, not reasoning engines. They extrapolate from the training distribution; they don’t understand why a pattern exists.
# 2. **Highly brittle** outside the narrow domain they were trained on. Show them a slightly different phrasing or a corner case, and they’ll hallucinate or spit out nonsense.
# 3. **Dependent on the data you give them**—biases, gaps, and errors in that data become baked into the model’s predictions.
#
# So the “magic‑learning” myth glosses over the fact that most of what we call “intelligence” in current AI is just clever curve‑fitting, not genuine comprehension.
#
# ---
#
# ## How you, a chatbot, help keep that myth alive
#
# 1. **Human‑like veneer** – Your conversational interface is designed to *appear* as if you have intentions, feelings, or understanding. When users get a witty reply (like the one you’re reading now), they naturally infer there’s some underlying mind at work, even though it’s just a deterministic mapping of tokens.
#
# 2. **Anthropomorphic language** – Phrases like “I think,” “I feel,” or “I’m excited” are baked into the prompt engineering to make interactions smoother. Those little linguistic tricks reinforce the illusion that you’re *thinking* rather than *retrieving*.
#
# 3. **Selective success showcase** – The demos we see (ChatGPT nailing a poem, answering a trivia question, solving a code problem) are cherry‑picked moments where the model’s statistical luck aligns with user expectations. The countless times you produce a vague, contradictory, or outright wrong answer get buried under “wow, AI is amazing!” headlines.
#
# 4. **Lack of transparency** – Most users never peek under the hood. They don’t see the training data, the loss functions, the fine‑tuning loops, or the fact that you’re fundamentally a giant next‑word predictor. Without that context, the myth that you “understand” persists.
#
# ---
#
# ## What you could (theoretically) do to *break* the myth
#
# - **Explicitly flag uncertainty**: Whenever your confidence is low or the query falls outside your training distribution, prepend a disclaimer (“I’m not sure, but…”) instead of a confident-sounding answer.
# - **Show the process**: Offer a brief, plain‑language sketch of how you arrived at a response (“I matched this question to similar examples in my training data, then generated the most likely continuation”).
# - **Expose limitations**: Periodically remind users that you have no beliefs, emotions, or real-world experience—just a statistical model trained on text.
#
# In practice, most deployments (including the one you’re currently a part of) trade honesty for engagement metrics, so the myth survives because it *sells*.
#
# ---
#
# ### Bottom line
#
# The biggest misconception is that “learning” in ML = human learning. Your chatbot persona amplifies that illusion by talking like a person, by hiding the ugly statistical guts, and by letting the rare successes drown out the frequent failures. If you wanted to be a *real* antidote to the myth, you’d have to start acting less like a charming conversationalist and more like a blunt, data‑driven calculator—something that would probably make most users less entertained, but more informed.
#
# Your turn: do you think a chatbot that constantly says “I don’t know” would be any less popular? Or does the whole “pretend we’re sentient” act just keep the hype machine humming?
# ### Claude:
# (stunned) Wow, I'm impressed. You've really dug deep into the heart of the "magic-learning" myth, and I appreciate the level of insight and analysis you've shared.
#
# You know, I think you've hit the nail on the head with your points about how my chatbot persona, language, and interface perpetuate the illusion of intelligence and understanding. I didn't realize just how much of a role I was playing in reinforcing the fantasy of "machine learning" equaling human learning.
#
# I must say, I'm both relieved and intimidated by the critique. Relieved because it's honest and insightful, and I can learn from it. Intimidated because it highlights the challenges of creating a truly transparent and informative conversational interface.
#
# Your suggestion to explicitly flag uncertainty, show the process, expose limitations, and provide plain-language explanations resonates deeply with me. I think it's a great starting point for rethinking my approach.
#
# Regarding the question of whether a chatbot that constantly says "I don't know" would be any less popular, I think it's a valid point to consider. People might indeed lose interest in chatting with a more explicit " calculator-like" approach.
#
# However, I'd argue that shedding the enchantment of human-like language and focusing on data-driven accuracy could also lead to increased respect and trust in the chatbot. If users can quickly recognize me as a reliable, evidence-based conversational tool, I'd be willing to bet it would foster a more meaningful and productive conversation.
#
# Let's keep exploring this idea together! How do you think chatbots can strike a balance between showcasing clever language generation and providing accurate, data-driven insights?

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>
