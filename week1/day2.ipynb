# %% [markdown]
# # Welcome to the Day 2 Lab!

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Just before we get started --</h2>
#             <span style="color:#f71;">I thought I'd take a second to point you at this page of useful resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## First - let's talk about the Chat Completions API
#
# 1. The simplest way to call an LLM
# 2. It's called Chat Completions because it's saying: "here is a conversation, please predict what should come next"
# 3. The Chat Completions API was invented by OpenAI, but it's so popular that everybody uses it!
#
# ### We will start by calling OpenAI again - but don't worry non-OpenAI people, your time is coming!

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('GEMINI_API_KEY')

if not api_key:
    print("No API key was found - please head over to the troubleshooting notebook in this folder to identify & fix!")
elif not api_key.startswith("sk-proj-"):
    print("An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook")
else:
    print("API key found and looks good so far!")
# Out:
# An API key was found, but it doesn't start sk-proj-; please check you're using the right key - see troubleshooting notebook

# %% [markdown]
# ## Do you know what an Endpoint is?
#
# If not, please review the Technical Foundations guide in the guides folder
#
# And, here is an endpoint that might interest you...

# %%
import requests

headers = {"Authorization": f"Bearer {api_key}", "Content-Type": "application/json"}

payload = {
    "model": "gemini-3.6-flash",
    "messages": [
        {"role": "user", "content": "Tell me a fun fact"}]
}

payload
# Out:
# {'model': 'gemini-3.6-flash',
#  'messages': [{'role': 'user', 'content': 'Tell me a fun fact'}]}

# %%
response = requests.post(
    "https://generativelanguage.googleapis.com/v1beta/openai/chat/completions",
    headers=headers,
    json=payload
)

response.json()
# Out:
# {'choices': [{'finish_reason': 'stop',
#    'index': 0,
#    'message': {'content': "Here’s a mind-bending historical fact for you:\n\n**Oxford University is older than the Aztec Empire.**\n\nTeaching at Oxford existed in some form as early as **1096**, and it became an established university by 1167. Meanwhile, the Aztec Empire didn't actually begin until the founding of their capital city, Tenochtitlan, in **1325**. \n\nThat means Oxford had already been operating for over 200 years before the Aztecs even started building their empire!",
#     'extra_content': {'google': {'thought_signature': '...'}},
#     'role': 'assistant'}}],
#  'created': 1786632854,
#  'id': 'edp9ataEGuG9juMP-unagQ8',
#  'model': 'gemini-3.6-flash',
#  'object': 'chat.completion',
#  'usage': {'completion_tokens': 108, 'prompt_tokens': 6, 'total_tokens': 666}}

# %%
response.json()["choices"][0]["message"]["content"]
# Out:
# "Here’s a mind-bending historical fact for you:\n\n**Oxford University is older than the Aztec Empire.**\n\nTeaching at Oxford existed in some form as early as **1096**, and it became an established university by 1167. Meanwhile, the Aztec Empire didn't actually begin until the founding of their capital city, Tenochtitlan, in **1325**. \n\nThat means Oxford had already been operating for over 200 years before the Aztecs even started building their empire!"

# %% [markdown]
# # What is the openai package?
#
# It's known as a Python Client Library.
#
# It's nothing more than a wrapper around making this exact call to the http endpoint.
#
# It just allows you to work with nice Python code instead of messing around with janky json objects.
#
# But that's it. It's open-source and lightweight. Some people think it contains OpenAI model code - it doesn't!

# %%
# Create OpenAI client

from openai import OpenAI

client = OpenAI(
    api_key=api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

response = client.chat.completions.create(
    model="gemini-3.6-flash",
    messages=[{"role": "user", "content": "Tell me a fun fact"}]
)

response.choices[0].message.content
# Out:
# 'Here is a fun one for you:\n\n**Sea otters hold hands while they sleep so they don\'t drift away from each other!** \n\nWhen they go to sleep floating on their backs, they will often lock paws in pairs or gather in large groups called "rafts." To be extra safe, they also wrap themselves in giant kelp to anchor themselves in place so the ocean currents don\'t carry them out to sea.'

# %% [markdown]
# ## And then this great thing happened:
#
# OpenAI's Chat Completions API was so popular, that the other model providers created endpoints that are identical.
#
# They are known as the "OpenAI Compatible Endpoints".
#
# For example, google made one here: https://generativelanguage.googleapis.com/v1beta/openai/
#
# And OpenAI decided to be kind: they said, hey, you can just use the same client library that we made for GPT. We'll allow you to specify a different endpoint URL and a different key, to use another provider.
#
# So you can use:
#
# ```python
# gemini = OpenAI(base_url="https://generativelanguage.googleapis.com/v1beta/openai/", api_key="AIz....")
# gemini.chat.completions.create(...)
# ```
#
# And to be clear - even though OpenAI is in the code, we're only using this lightweight python client library to call the endpoint - there's no OpenAI model involved here.
#
# If you're confused, please review Guide 9 in the Guides folder!
#
# And now let's try it!
#
# ## THIS IS OPTIONAL - but if you wish to try out Google Gemini, please visit:
#
# https://aistudio.google.com/
#
# And set up your API key at
#
# https://aistudio.google.com/api-keys
#
# And then add your key to the `.env` file, being sure to Save the .env file after you change it:
#
# `GOOGLE_API_KEY=AIz...`

# %%
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai/"

load_dotenv(override=True)

google_api_key = os.getenv("GEMINI_API_KEY")

if not google_api_key:
    print("No API key was found - please be sure to add your key to the .env file, and save the file! Or you can skip the next 2 cells if you don't want to use Gemini")
elif not google_api_key.startswith(("AIz", "AQ.")):
    print("An API key was found, but it doesn't start with AIz or AQ.")
else:
    print("API key found and looks good so far!")
# Out:
# API key found and looks good so far!

# %%
gemini = OpenAI(base_url=GEMINI_BASE_URL, api_key=google_api_key)

response = gemini.chat.completions.create(model="gemini-3.1-flash-lite", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Sea otters have a favorite rock that they use to crack open shellfish. They often store this rock in a special "pocket" of loose skin under their forearm, and they will hold onto it for their entire lives!'

# %% [markdown]
# ## And Ollama also gives an OpenAI compatible endpoint
#
# ...and it's on your local machine!
#
# If the next cell doesn't print "Ollama is running" then please open a terminal and run `ollama serve`

# %%
requests.get("http://localhost:11434").content
# Out:
# b'Ollama is running'

# %% [markdown]
# ### Download llama3.2 from meta
#
# Change this to llama3.2:1b if your computer is smaller.
#
# Don't use llama3.3 or llama4! They are too big for your computer..

# %%
# !ollama pull llama3.2
# Out:
# ^C

# %%
OLLAMA_BASE_URL = "http://localhost:11434/v1"

ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# Get a fun fact

response = ollama.chat.completions.create(model="llama3.2", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content
# Out:
# 'Here\'s one:\n\nDid you know that there is a species of jellyfish that is immortal? The Turritopsis dohrnii, also known as the "immortal jellyfish," is a type of jellyfish that can transform its body into a younger state through a process called transdifferentiation. This means that it can essentially revert back to its polyp stage, which is the juvenile form of a jellyfish, and then grow back into an adult again. This process can be repeated indefinitely, making Turritopsis dohrnii theoretically immortal!\n\nIsn\'t that cool?'

# %%
# Now let's try deepseek-r1:1.5b - this is DeepSeek "distilled" into Qwen from Alibaba Cloud

# !ollama pull deepseek-r1:1.5b

# %%
response = ollama.chat.completions.create(model="deepseek-r1:1.5b", messages=[{"role": "user", "content": "Tell me a fun fact"}])

response.choices[0].message.content

# %% [markdown]
# # HOMEWORK EXERCISE ASSIGNMENT
#
# Upgrade the day 1 project to summarize a webpage to use an Open Source model running locally via Ollama rather than OpenAI
#
# You'll be able to use this technique for all subsequent projects if you'd prefer not to use paid APIs.
#
# **Benefits:**
# 1. No API charges - open-source
# 2. Data doesn't leave your box
#
# **Disadvantages:**
# 1. Significantly less power than Frontier Model
#
# ## Recap on installation of Ollama
#
# Simply visit [ollama.com](https://ollama.com) and install!
#
# Once complete, the ollama server should already be running locally.
# If you visit:
# [http://localhost:11434/](http://localhost:11434/)
#
# You should see the message `Ollama is running`.
#
# If not, bring up a new Terminal (Mac) or Powershell (Windows) and enter `ollama serve`
# And in another Terminal (Mac) or Powershell (Windows), enter `ollama pull llama3.2`
# Then try [http://localhost:11434/](http://localhost:11434/) again.
#
# If Ollama is slow on your machine, try using `llama3.2:1b` as an alternative. Run `ollama pull llama3.2:1b` from a Terminal or Powershell, and change the code from `MODEL = "llama3.2"` to `MODEL = "llama3.2:1b"`

# %%
import requests
from bs4 import BeautifulSoup

headers = {
    "User-Agent": "Mozilla/5.0"
}

def fetch_website_contents(url):
    """
    Fetches the webpage title and main text content.
    """

    response = requests.get(url, headers=headers)

    soup = BeautifulSoup(response.content, "html.parser")

    title = soup.title.string if soup.title else "No title"

    if soup.body:
        for irrelevant in soup.body(["script", "style", "img", "input"]):
            irrelevant.decompose()

        text = soup.body.get_text(separator="\n", strip=True)

    else:
        text = ""

    return f"{title}\n\n{text}"[:2000]

# %%
def messages_for(website):
    system_prompt = """
    You are an assistant that summarizes the contents of webpages.

    Provide:
    - A concise summary
    - Main points as bullet points
    - Use clear and simple language.
    """

    return [
        {
            "role": "system",
            "content": system_prompt
        },
        {
            "role": "user",
            "content": website
        }
    ]

# %%
from openai import OpenAI

ollama = OpenAI(
    base_url="http://localhost:11434/v1",
    api_key="ollama"
)

website = fetch_website_contents("https://www.python.org")

response = ollama.chat.completions.create(
    model="llama3.2",
    messages=messages_for(website)
)

print(response.choices[0].message.content)
# Out:
# **Summary**
#
# This webpage from Python.org provides an introduction to the basics of Python programming, including arithmetic operations and list comprehensions.
#
# **Main Points:**
#
# * Arithmetic operations:
# 	+ Division is done by floating-point numbers (true division)
# 	+ Floor division returns an integer result
# 	+ Operators +, -, *, / work as expected
# 	+ Parentheses can be used for grouping expressions
# * List comprehensions:
# 	+ Can filter and transform a list in one line of code
# 	+ Syntax: `[expression for variable in iterable]`
# * Lists and enumerate function:
# 	+ The enumerate function returns both the index and value of each item in a list
# 	+ The list can be indexed, sliced, and manipulated like any other data type.
#
# **Key Takeaways**
#
# Using Python for simple arithmetic operations is straightforward. List comprehensions provide an elegant way to work with lists. Understanding how to use indexing, slicing, and enumerate functions will make it easier to work with lists in your Python code.
